# %% [markdown]
# > # **4. Aplicación de Modelos de Deep Learning**

# %% [markdown]
# En esta etapa nos enfocaremos en la aplicación de distintos modelos de Deep Learning. Utilizaremos herramientas/bibliotecas como ***TensorFlow*** y ***Keras***. Pero antes de ingresar a la parte de modelado haremos una recapitulacion de la información que obtuvimos en las fases anteriores (**EDA**).

# %% [markdown]
# A priori sabemos que hay un ***Desbalanceo en las clases*** lo cuál puede tender a generar un ***Sobreajuste (Overfitting)*** en el modelado.
#
# % de datos/imágenes en cada clase:
# *
# *
# *
# *

# %% [markdown]
# Metricas: hablar y explicar las métricas que se van a utilizar.

# %% [markdown]
# Mencionar y explicar cuales modelos aplicamos

# %% [markdown]
# ## **Bibliografía**
#
# * Modelos utlizados de TensorFlow Hub: **[Kaggle Models](https://www.kaggle.com/models?tfhub-redirect=true&orderby=voteCount&task=16686&datatype=14102/)**
